# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import f1_score, accuracy_score, confusion_matrix
import seaborn as sns
from tkinter import Tk
from tkinter import messagebox
import sys 
import urllib
import urllib.request

# %%
kids=pd.read_csv("/content/kids.csv")
kids.head()
# Out:
#             Disease  Symptom_1             Symptom_2             Symptom_3  \
# 0  Fungal infection    itching             skin_rash  nodal_skin_eruptions
# 1  Fungal infection  skin_rash  nodal_skin_eruptions   dischromic _patches
# 2  Fungal infection    itching  nodal_skin_eruptions   dischromic _patches
# 3  Fungal infection    itching             skin_rash   dischromic _patches
# 4  Fungal infection    itching             skin_rash  nodal_skin_eruptions
#
#              Symptom_4 Symptom_5 Symptom_6 Symptom_7 Symptom_8 Symptom_9  \
# 0  dischromic _patches       NaN       NaN       NaN       NaN       NaN
# 1                  NaN       NaN       NaN       NaN       NaN       NaN
# 2                  NaN       NaN       NaN       NaN       NaN       NaN
# 3                  NaN       NaN       NaN       NaN       NaN       NaN
# 4                  NaN       NaN       NaN       NaN       NaN       NaN
#
#   Symptom_10 Symptom_11 Symptom_12 Symptom_13 Symptom_14 Symptom_15  \
# ...

# %%
kids.shape
# Out:
# (4920, 18)

# %%
adult=pd.read_csv("/content/adults.csv")
adult.head()
# Out:
#             Disease  Symptom_1             Symptom_2             Symptom_3  \
# 0  Fungal infection    itching             skin_rash  nodal_skin_eruptions
# 1  Fungal infection  skin_rash  nodal_skin_eruptions   dischromic _patches
# 2  Fungal infection    itching  nodal_skin_eruptions   dischromic _patches
# 3  Fungal infection    itching             skin_rash   dischromic _patches
# 4  Fungal infection    itching             skin_rash  nodal_skin_eruptions
#
#              Symptom_4 Symptom_5 Symptom_6 Symptom_7 Symptom_8 Symptom_9  \
# 0  dischromic _patches       NaN       NaN       NaN       NaN       NaN
# 1                  NaN       NaN       NaN       NaN       NaN       NaN
# 2                  NaN       NaN       NaN       NaN       NaN       NaN
# 3                  NaN       NaN       NaN       NaN       NaN       NaN
# 4                  NaN       NaN       NaN       NaN       NaN       NaN
#
#   Symptom_10 Symptom_11 Symptom_12 Symptom_13 Symptom_14 Symptom_15  \
# ...

# %%
adult.shape
# Out:
# (4920, 18)

# %%
old=pd.read_csv("/content/old.csv")
old.head()
# Out:
#             Disease  Symptom_1             Symptom_2             Symptom_3  \
# 0  Fungal infection    itching             skin_rash  nodal_skin_eruptions
# 1  Fungal infection  skin_rash  nodal_skin_eruptions   dischromic _patches
# 2  Fungal infection    itching  nodal_skin_eruptions   dischromic _patches
# 3  Fungal infection    itching             skin_rash   dischromic _patches
# 4  Fungal infection    itching             skin_rash  nodal_skin_eruptions
#
#              Symptom_4   Symptom_5 Symptom_6 Symptom_7 Symptom_8 Symptom_9  \
# 0  dischromic _patches      chills       NaN       NaN       NaN       NaN
# 1                  NaN  high_fever    chills       NaN       NaN       NaN
# 2                  NaN      chills       NaN       NaN       NaN       NaN
# 3                  NaN  high_fever       NaN       NaN       NaN       NaN
# 4                  NaN      chills       NaN       NaN       NaN       NaN
#
# ...

# %%
sy=pd.read_csv("/content/Symptom-severity.csv")
sy.head()
# Out:
#                 Symptom  weight
# 0               itching       1
# 1             skin_rash       3
# 2  nodal_skin_eruptions       4
# 3   continuous_sneezing       4
# 4             shivering       5

# %%
sy.shape
# Out:
# (138, 2)

# %%
age=int(input("enter the age="))
# Out:
# enter the age=13

# %% [markdown]
# **KNEIGHBOUR CLASSIFIER**

# %%
if age<=14:
  kids.isna().sum()
  kids.isnull().sum()
  cols = kids.columns
  data = kids[cols].values.flatten()
  s = pd.Series(data)
  s = s.str.strip()
  s = s.values.reshape(kids.shape)
  kids = pd.DataFrame(s, columns=kids.columns)
  kids = kids.fillna(0)
  kids.head()
  vals = kids.values
  symptoms = sy['Symptom'].unique()
  for i in range(len(symptoms)):
      vals[vals == symptoms[i]] = sy[sy['Symptom'] == symptoms[i]]['weight'].values[0]  
  d = pd.DataFrame(vals, columns=cols)
  d = d.replace('dischromic _patches', 0)
  d = d.replace('spotting_ urination',0)
  kids = d.replace('foul_smell_of urine',0)
  kids.head()
  (kids[cols] == 0).all()
  kids['Disease'].value_counts()
  kids['Disease'].unique()
  datak = kids.iloc[:,2:].values
  labelsk= kids['Disease'].values
  x_train, x_test, y_train, y_test = train_test_split(datak, labelsk)
  print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
  model = KNeighborsClassifier()
  model.fit(x_train, y_train)
  preds = model.predict(x_test)
  print(preds)
  conf_mat = confusion_matrix(y_test, preds)
  df_cm = pd.DataFrame(conf_mat, index=kids['Disease'].unique(), columns=kids['Disease'].unique())
  print('F1-score% =', f1_score(y_test, preds, average='macro')*100, '|', 'Accuracy% =', accuracy_score(y_test, preds)*100)
  sns.heatmap(df_cm)
elif 14<age<=55:
  adult.isna().sum()
  adult.isnull().sum()
  cols = adult.columns
  data = adult[cols].values.flatten()
  s = pd.Series(data)
  s = s.str.strip()
  s = s.values.reshape(adult.shape)
  adult = pd.DataFrame(s, columns=adult.columns)
  adult = adult.fillna(0)
  adult.head()
  vals = adult.values
  symptoms = sy['Symptom'].unique()
  for i in range(len(symptoms)):
      vals[vals == symptoms[i]] = sy[sy['Symptom'] == symptoms[i]]['weight'].values[0]  
  d = pd.DataFrame(vals, columns=cols)
  d = d.replace('dischromic _patches', 0)
  d = d.replace('spotting_ urination',0)
  adult= d.replace('foul_smell_of urine',0)
  adult.head()
  (adult[cols] == 0).all()
  adult['Disease'].value_counts()
  adult['Disease'].unique()
  dataa = adult.iloc[:,2:].values
  labelsa= adult['Disease'].values
  x_train, x_test, y_train, y_test = train_test_split(dataa, labelsa)
  print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
  model =KNeighborsClassifier()
  model.fit(x_train, y_train)
  preds = model.predict(x_test)
  print(preds)
  conf_mat = confusion_matrix(y_test, preds)
  df_cm = pd.DataFrame(conf_mat, index=adult['Disease'].unique(), columns=adult['Disease'].unique())
  print('F1-score% =', f1_score(y_test, preds, average='macro')*100, '|', 'Accuracy% =', accuracy_score(y_test, preds)*100)
  sns.heatmap(df_cm)
else:
  old.isna().sum()
  old.isnull().sum()
  cols = old.columns
  data = old[cols].values.flatten()
  s = pd.Series(data)
  s = s.str.strip()
  s = s.values.reshape(old.shape)
  old= pd.DataFrame(s, columns=old.columns)
  old= kids.fillna(0)
  old.head()
  vals = old.values
  symptoms = sy['Symptom'].unique()
  for i in range(len(symptoms)):
      vals[vals == symptoms[i]] = sy[sy['Symptom'] == symptoms[i]]['weight'].values[0]  
  d = pd.DataFrame(vals, columns=cols)
  d = d.replace('dischromic _patches', 0)
  d = d.replace('spotting_ urination',0)
  old= d.replace('foul_smell_of urine',0)
  old.head()
  (old[cols] == 0).all()
  old['Disease'].value_counts()
  old['Disease'].unique()
  datao = old.iloc[:,2:].values
  labelso= old['Disease'].values
  x_train, x_test, y_train, y_test = train_test_split(datao, labelso)
  print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
  model = KNeighborsClassifier()
  model.fit(x_train, y_train)
  preds = model.predict(x_test)
  print(preds)
  conf_mat = confusion_matrix(y_test, preds)
  df_cm = pd.DataFrame(conf_mat, index=old['Disease'].unique(), columns=old['Disease'].unique())
  print('F1-score% =', f1_score(y_test, preds, average='macro')*100, '|', 'Accuracy% =', accuracy_score(y_test, preds)*100)
  sns.heatmap(df_cm)
# Out:
# (3690, 16) (1230, 16) (3690,) (1230,)
# ['Dimorphic hemmorhoids(piles)' 'hepatitis A' 'Diabetes' ...
#  'Varicose veins' 'Pneumonia' 'Drug Reaction']
# F1-score% = 97.48094367200103 | Accuracy% = 97.5609756097561
